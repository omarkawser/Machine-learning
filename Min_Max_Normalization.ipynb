# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the data 
from google.colab import files
uploaded=files.upload()
df = pd.read_csv('features_30_sec.csv')
# Out:
#      <input type="file" id="files-3868668b-b6e7-4d68-a91a-9640e54352b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3868668b-b6e7-4d68-a91a-9640e54352b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving features_30_sec.csv to features_30_sec.csv

# %%
df.head()
# Out:
#           filename  length  chroma_stft_mean  ...  mfcc20_mean  mfcc20_var  label
# 0  blues.00000.wav  661794          0.350088  ...     1.221291   46.936035  blues
# 1  blues.00001.wav  661794          0.340914  ...     0.531217   45.786282  blues
# 2  blues.00002.wav  661794          0.363637  ...    -2.231258   30.573025  blues
# 3  blues.00003.wav  661794          0.404785  ...    -3.407448   31.949339  blues
# 4  blues.00004.wav  661794          0.308526  ...   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %%
#Preprocesing
df['filename'].unique()

# %%
df['filename'] = df['filename'].astype('category')
df['class_label'] = df['filename'].cat.codes

# %%
lookup_genre_name = dict(zip(df.class_label.unique(), df.filename.unique()))   
lookup_genre_name

# %%
df['filename'].unique()

# %%
cols = list(df.columns)
cols.remove('label')
cols.remove('class_label')
cols.remove('filename')
#df[cols]

# %%
#Data Splitting for Training and Testing
# %matplotlib notebook
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
X = df.iloc[:,1:28]
y = df['class_label']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.25, random_state=3)

# %%
#Min-Max Normalization

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
# we must apply the scaling to the test set that we computed for the training set
X_test_scaled = scaler.transform(X_test)

# %%
#Random Forest classification
from sklearn.ensemble import RandomForestClassifier
# %matplotlib notebook
clf = RandomForestClassifier(random_state=0, n_jobs=-1).fit(X_train_scaled, y_train)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), names, rotation=90)
plt.show()
# Out:
# <div id='3f18e0d8-d5e5-4243-92fb-ea8821119ddd'></div>

# %%
#Decision Tree

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0).fit(X_train_scaled, y_train)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), names, rotation=90)
plt.show()
# Out:
# <div id='b00c7c1c-7e8f-4663-94a4-966067ebab6a'></div>

# %%
#K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 13)
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test)
# Out:
# 0.0
